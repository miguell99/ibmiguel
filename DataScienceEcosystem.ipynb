# %% [markdown]
# #Data Science Tools and Ecosystem:

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
#
# - List popular languages for Data Science
# - Identify key tools and frameworks used in Data Science
# - Understand the basics of arithmetic expressions in Python
# - Learn how to convert time units in programming
# - Explore integrated development environments (IDEs) for data analysis

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1.  Python
# 2.  R
# 3. SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. NumPy
# 3. SciPy
# 4. Scikit-learn
# 5. TensorFlow
# 6. PyTorch

# %% [markdown]
# | Data Science Tools         |
# |----------------------------|
# | Jupyter Notebook            |
# | RStudio                     |
# | Spyder                      |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
(3*4) + 5 #This a simple arithmetic expression to mutiply then add integers
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60.
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
#
# Miguel
